# %% [markdown]
# <a href="https://colab.research.google.com/github/pornpailinjanjit/data_viz/blob/main/Quiz3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data_csv = pd.read_csv('-.57-.58-1.csv', encoding='iso-8859-11')
data_csv
# Out:
#                                           Unnamed: 0  ...                แบบ สขร. 1
# 0   สรุปผลการดำเนินการจัดซื้อในรอบเดือน พฤษภาคม 2558  ...                       NaN
# 1         สำนักงานปลัดกระทรวงวิทยาศาสตร์และเทคโนโลยี  ...                       NaN
# 2                                                NaN  ...                       NaN
# 3                                              ลำดับ  ...  เหตุผลที่คัดเลือกโดยสรุป
# 4                                                ที่  ...                       NaN
# ..                                               ...  ...                       ...
# 78                                                56  ...            เป็นผู้จำหน่าย
# 79                                                57  ...            เป็นผู้จำหน่าย
# 80                                                58  ...            เป็นผู้จำหน่าย
# 81                                                59  ...            เป็นผู้จำหน่าย
# ...

# %%
data_csv1 = pd.read_csv('-.57-.58-1 (1).csv', encoding='iso-8859-11',header=4)
data_csv1
# Out:
#                                               ลำดับ  ...  เหตุผลที่คัดเลือกโดยสรุป
# 0                                               ที่  ...                       NaN
# 1                                                 1  ...            เป็นผู้รับจ้าง
# 2                                                 2  ...            เป็นผู้รับจ้าง
# 3                                                 3  ...            เป็นผู้รับจ้าง
# 4                                                 4  ...            เป็นผู้รับจ้าง
# 5                                                 5  ...            เป็นผู้รับจ้าง
# 6                                                 6  ...            เป็นผู้รับจ้าง
# 7                                                 7  ...            เป็นผู้รับจ้าง
# 8                                                 8  ...            เป็นผู้รับจ้าง
# 9                                                 9  ...            เป็นผู้รับจ้าง
# ...

# %%
import pandas as pd

# %%
oct57 = pd.read_excel('-.57-.58-1.xls',sheet_name=0,header=4,skipfooter=20)
oct57
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 0    ที่  ...                      NaN
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...  เป็นผู้ให้บริการจำหน่าย
# 3      3  ...  เป็นผู้ให้บริการจำหน่าย
# 4      4  ...  เป็นผู้ให้บริการจำหน่าย
# 5      5  ...  เป็นผู้ให้บริการจำหน่าย
# 6      6  ...  เป็นผู้ให้บริการจำหน่าย
# 7      7  ...  เป็นผู้ให้บริการจำหน่าย
# 8      8  ...  เป็นผู้ให้บริการจำหน่าย
# 9      9  ...  เป็นผู้ให้บริการจำหน่าย
# 10    10  ...  เป็นผู้ให้บริการจำหน่าย
# 11    11  ...  เป็นผู้ให้บริการจำหน่าย
# 12    12  ...  เป็นผู้ให้บริการจำหน่าย
# 13    13  ...  เป็นผู้ให้บริการจำหน่าย
# 14    14  ...  เป็นผู้ให้บริการจำหน่าย
# 15    15  ...  เป็นผู้ให้บริการจำหน่าย
#
# [16 rows x 9 columns]

# %%
oct57 = pd.read_excel('-.57-.58-1.xls',sheet_name=0,header=4,skipfooter=20)
oct57 = oct57.dropna()
oct57
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...  เป็นผู้ให้บริการจำหน่าย
# 3      3  ...  เป็นผู้ให้บริการจำหน่าย
# 4      4  ...  เป็นผู้ให้บริการจำหน่าย
# 5      5  ...  เป็นผู้ให้บริการจำหน่าย
# 6      6  ...  เป็นผู้ให้บริการจำหน่าย
# 7      7  ...  เป็นผู้ให้บริการจำหน่าย
# 8      8  ...  เป็นผู้ให้บริการจำหน่าย
# 9      9  ...  เป็นผู้ให้บริการจำหน่าย
# 10    10  ...  เป็นผู้ให้บริการจำหน่าย
# 11    11  ...  เป็นผู้ให้บริการจำหน่าย
# 12    12  ...  เป็นผู้ให้บริการจำหน่าย
# 13    13  ...  เป็นผู้ให้บริการจำหน่าย
# 14    14  ...  เป็นผู้ให้บริการจำหน่าย
# 15    15  ...  เป็นผู้ให้บริการจำหน่าย
#
# [15 rows x 9 columns]

# %%
oct57.rename(columns={'Unnamed: 5':'ราคาเสนอ','Unnamed: 7':'ราคาซื้อ'}) #เปลี่ยนชื่อหัวตาราง
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...  เป็นผู้ให้บริการจำหน่าย
# 3      3  ...  เป็นผู้ให้บริการจำหน่าย
# 4      4  ...  เป็นผู้ให้บริการจำหน่าย
# 5      5  ...  เป็นผู้ให้บริการจำหน่าย
# 6      6  ...  เป็นผู้ให้บริการจำหน่าย
# 7      7  ...  เป็นผู้ให้บริการจำหน่าย
# 8      8  ...  เป็นผู้ให้บริการจำหน่าย
# 9      9  ...  เป็นผู้ให้บริการจำหน่าย
# 10    10  ...  เป็นผู้ให้บริการจำหน่าย
# 11    11  ...  เป็นผู้ให้บริการจำหน่าย
# 12    12  ...  เป็นผู้ให้บริการจำหน่าย
# 13    13  ...  เป็นผู้ให้บริการจำหน่าย
# 14    14  ...  เป็นผู้ให้บริการจำหน่าย
# 15    15  ...  เป็นผู้ให้บริการจำหน่าย
#
# [15 rows x 9 columns]

# %% [markdown]
# #HW8

# %%
nov57 = pd.read_excel('-.57-.58-1.xls', sheet_name=1, header=4,skipfooter=20)
nov57 = nov57.dropna()
nov57
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...           เป็นผู้จำหน่าย
# 3      3  ...           เป็นผู้จำหน่าย
# 4      4  ...           เป็นผู้จำหน่าย
# 5      5  ...           เป็นผู้จำหน่าย
# 6      6  ...           เป็นผู้จำหน่าย
# 7      7  ...           เป็นผู้จำหน่าย
# 8      8  ...           เป็นผู้จำหน่าย
# 9      9  ...           เป็นผู้จำหน่าย
# 10    10  ...           เป็นผู้จำหน่าย
# 11    11  ...           เป็นผู้จำหน่าย
# 12    12  ...           เป็นผู้จำหน่าย
# 13    13  ...           เป็นผู้จำหน่าย
# 14    14  ...           เป็นผู้จำหน่าย
# 15    15  ...           เป็นผู้จำหน่าย
# 22    16  ...           เป็นผู้จำหน่าย
# 23    17  ...           เป็นผู้จำหน่าย
# 24    18  ...           เป็นผู้จำหน่าย
# 25    19  ...           เป็นผู้จำหน่าย
# 26    20  ...           เป็นผู้จำหน่าย
# 27    21  ...           เป็นผู้จำหน่าย
# 28    22  ...           เป็นผู้จำหน่าย
# 29    23  ...           เป็นผู้จำหน่าย
# ...

# %%
nov57.rename(columns={'Unnamed: 5':'ราคาเสนอ', 'Unnamed: 7':'ราคาซื้อ'})
# Out:
#    ลำดับ  ... เหตุผลที่คัดเลือกโดยสรุป
# 1      1  ...  เป็นผู้ให้บริการจำหน่าย
# 2      2  ...           เป็นผู้จำหน่าย
# 3      3  ...           เป็นผู้จำหน่าย
# 4      4  ...           เป็นผู้จำหน่าย
# 5      5  ...           เป็นผู้จำหน่าย
# 6      6  ...           เป็นผู้จำหน่าย
# 7      7  ...           เป็นผู้จำหน่าย
# 8      8  ...           เป็นผู้จำหน่าย
# 9      9  ...           เป็นผู้จำหน่าย
# 10    10  ...           เป็นผู้จำหน่าย
# 11    11  ...           เป็นผู้จำหน่าย
# 12    12  ...           เป็นผู้จำหน่าย
# 13    13  ...           เป็นผู้จำหน่าย
# 14    14  ...           เป็นผู้จำหน่าย
# 15    15  ...           เป็นผู้จำหน่าย
# 22    16  ...           เป็นผู้จำหน่าย
# 23    17  ...           เป็นผู้จำหน่าย
# 24    18  ...           เป็นผู้จำหน่าย
# 25    19  ...           เป็นผู้จำหน่าย
# 26    20  ...           เป็นผู้จำหน่าย
# 27    21  ...           เป็นผู้จำหน่าย
# 28    22  ...           เป็นผู้จำหน่าย
# 29    23  ...           เป็นผู้จำหน่าย
# ...
