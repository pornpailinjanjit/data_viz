# %% [markdown]
# <a href="https://colab.research.google.com/github/pornpailinjanjit/data_viz/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data63 = pd.read_excel('passenger-covid19.xlsx',sheet_name=0)
data63
# Out:
#    ขนคน/ขนสินค้า โหมดการเดินทาง  ...   พ.ย. 2562   ธ.ค. 2562
# 0      ขนคน (คน)          ทางบก  ...   4559610.0   4840673.0
# 1      ขนคน (คน)          ทางบก  ...         NaN         NaN
# 2      ขนคน (คน)          ทางบก  ...   2450888.0   2516032.0
# 3     ขนคน (คัน)          ทางบก  ...  28325020.0  29615013.0
# 4     ขนคน (คัน)          ทางบก  ...  46996660.0  47294111.0
# 5     ขนคน (คัน)          ทางบก  ...         NaN         NaN
# 6      ขนคน (คน)          ทางบก  ...    108037.0    104032.0
# 7      ขนคน (คน)          ทางบก  ...         NaN         NaN
# 8      ขนคน (คน)          ทางบก  ...  29672244.0  29019427.0
# 9      ขนคน (คน)          ทางบก  ...  25368180.0  24993204.0
# 10    ขนคน (คัน)          ทางบก  ...         NaN         NaN
# 11    ขนคน (คัน)          ทางบก  ...         NaN         NaN
# 12     ขนคน (คน)         ทางน้ำ  ...         NaN         NaN
# 13     ขนคน (คน)         ทางน้ำ  ...    771668.0    766378.0
# ...

# %%
data63['ยานพาหนะ/ท่า']
# Out:
# 0                      รถ ขบส. และ รถร่วม
# 1                                 รถ Taxi
# 2                                รถหมวด 3
# 3                    รถยนต์ (10 จุดสำรวจ)
# 4                        รถยนต์ (ทางด่วน)
# 5                           รถจักรยานยนต์
# 6                                รถหมวด 4
# 7                    รถจักรยานยนต์รับจ้าง
# 8                            รถเมล์ ขสมก.
# 9                         รถร่วม (หมวด 1)
# 10                                 รถยนต์
# 11                          รถจักรยานยนต์
# 12                            เรือภูมิภาค
# 13                          เรือเจ้าพระยา
# 14                         เรือคลองแสนแสบ
# 15                            เรือภูมิภาค
# 16                          เรือส่วนบุคคล
# 17                                   รถไฟ
# 18                    รถไฟฟ้าสายสีน้ำเงิน
# 19                       รถไฟฟ้าสายสีม่วง
# 20                            รถไฟฟ้า ARL
# 21                            รถไฟฟ้า BTS
# ...

# %%
data = data63[data63['ยานพาหนะ/ท่า']=='ท่าอากาศยานดอนเมือง ขาออกประเทศ']
data
# Out:
#    ขนคน/ขนสินค้า โหมดการเดินทาง  ... พ.ย. 2562 ธ.ค. 2562
# 35     ขนคน (คน)       ทางอากาศ  ...  676655.0  744031.0
#
# [1 rows x 18 columns]
